# %%
import pandas as pd  
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np  
import seaborn as sns
import pylab
from sklearn.preprocessing import StandardScaler

# %%
dataset = pd.read_csv('data1.txt', sep=",", header=None, names = ['x','y'])
dataset.describe()
# Out:
#                x          y
# count  97.000000  97.000000
# mean    8.159800   5.839135
# std     3.869884   5.510262
# min     5.026900  -2.680700
# 25%     5.707700   1.986900
# 50%     6.589400   4.562300
# 75%     8.578100   7.046700
# max    22.203000  24.147000

# %%
sns.jointplot(x="x", y="y", data=dataset, kind='scatter');

# %%
sns.regplot(x="x", y="y", data=dataset);

# %%
def straight (Q0, Q1, X): 
    return Q0+Q1*X;
def ErrorFunc(Qf0, Qf1, X, Y):
    return (Qf0 + Qf1*X - Y)**2;

# %%
numberIterations = 15000
alpha = 0.0005 #[0.001;0.1]
Q0 = 0; Q1 = 0;
tmp0 = 0; tmp1 = 0;
m = dataset['x'].size; 
i = 0
numberFrame = 0;
J = []
JStep = []
ConstStep = 1
IterStep = 0

while (i < numberIterations):
    if (numberFrame == m):
        numberFrame = 0;
        
    tmp0 = Q0 - alpha * 2*(straight(Q0, Q1, dataset['x'][numberFrame]) - dataset['y'][numberFrame])
    tmp1 = Q1 - alpha * 2*(straight(Q0, Q1, dataset['x'][numberFrame]) - dataset['y'][numberFrame])*dataset['x'][numberFrame]

    Q0 = tmp0
    Q1 = tmp1

    J.append(ErrorFunc(Q0,Q1,dataset['x'].mean(), dataset['y'].mean()))
    
    if (ConstStep == IterStep):
        tmp = 0; 
        IterStep = 0;
    
    
    
    numberFrame = numberFrame + 1; 
    i = i+1
    IterStep = IterStep + 1 
    

print ("Q0 =" + str (Q0))
print ("Q1 =" + str (Q1))
print (str (Q1) + "x + " + str (Q0) + " = y ")
# Out:
# Q0 =-3.5113464863930517
# Q1 =1.0196176372007053
# 1.0196176372007053x + -3.5113464863930517 = y

# %%
grid = sns.JointGrid(dataset['x'], dataset['y'], space=0, size=6, ratio=50)
grid.plot_joint(plt.scatter, color="b")
plt.plot([dataset['x'].min(), dataset['x'].max()], [straight(Q0,Q1,dataset['x'].min()), straight(Q0,Q1,dataset['x'].max())], linewidth=2)
# Out:
# /home/mamoru/.local/lib/python2.7/site-packages/seaborn/axisgrid.py:1672: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# /home/mamoru/.local/lib/python2.7/site-packages/matplotlib/tight_layout.py:198: UserWarning: tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('tight_layout cannot make axes width small enough '
# /home/mamoru/.local/lib/python2.7/site-packages/matplotlib/tight_layout.py:209: UserWarning: tight_layout cannot make axes height small enough to accommodate all axes decorations
#   warnings.warn('tight_layout cannot make axes height small enough '

# %%
smooth_err = [sum(J[i:i+m]) / m for i in range(len(J)-m)]
smooth_step = range(len(smooth_err))
sns.lineplot(x=smooth_step,y = smooth_err, sort=True, lw=1)

# %%
print (dataset['x'].mean())
# Out:
# 8.159799999999999

# %%
ax = axes3d.Axes3D(plt.figure())

rangeR = 10
step = 0.5

iX = np.arange(Q0 - rangeR, Q0 + rangeR, step)
iY = np.arange(Q1 - rangeR, Q1 + rangeR, step)
X, Y = np.meshgrid(iX, iY)
Z = ErrorFunc(X, Y,dataset['x'].mean(), dataset['y'].mean())
ax.plot_wireframe(X, Y, Z, rstride=1, cstride=1)

plt.show()

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

fig = plt.figure()
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,cmap='viridis',edgecolor='none')
